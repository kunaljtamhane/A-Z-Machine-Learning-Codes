# %% [markdown]
# # Where to Collect Data for Machine Learning?

# %% [markdown]
# #### Agenda
# ##### 1. Importance of Data in Machine Learning
# ##### 2. Where to Collect the Data?
# ##### 3. Demonstration of Data Collection

# %% [markdown]
# Example: we have images of Dogs and Cats and we want a system to see these images and recognise whether the image is of Dog or Cat. What we can do is we can feed images to our machine learning model and find pattern in the images.

# %% [markdown]
# ![image.png](attachment:eab951b5-230b-46bd-9158-63171bb75f92.png)

# %% [markdown]
# ### Where to collect the Data From?
# 1. Kaggle
# 2. Google Dataset Search
# 3. UCI Machine learning Repository

# %%
import pandas as pd

# %%
# Loading Dataset to a pandas dataframe
dataset = pd.read_csv('housing.csv')

# %%
dataset.head()
# Out:
#   0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...
